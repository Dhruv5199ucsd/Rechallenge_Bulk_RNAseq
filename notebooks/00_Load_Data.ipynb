# %%
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
sc.settings.verbosity = 3


print(sc.__version__)
# Out:
# 1.12.1
# /tmp/ipykernel_3711125/4172891791.py:8: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(sc.__version__)

# %%
from pathlib import Path 
import sys

# %%
sys.path.append("/home/dk5299/Projects_31926/RNA-seq/Kallies_Sci_Immuno_2025")

# %%
from src.paths import DATA_DIR, INTERMEDIATE_DIR, RESULTS_DIR

print("DATA_DIR:", DATA_DIR  )
print(INTERMEDIATE_DIR)
print(RESULTS_DIR)
# Out:
# DATA_DIR: /mnt/sata4/Dhruv_2025/Projects_31926/RNA_Seq/Kallies_Sci_Immuno_2025/data
# /mnt/sata4/Dhruv_2025/Projects_31926/RNA_Seq/Kallies_Sci_Immuno_2025/objects
# /mnt/sata4/Dhruv_2025/Projects_31926/RNA_Seq/Kallies_Sci_Immuno_2025/results

# %%
adata = sc.read_10x_mtx(
    "/mnt/sata4/Dhruv_2025/Projects_31926/RNA_Seq/Kallies_Sci_Immuno_2025/data",
    var_names="gene_symbols",
    make_unique=True,
    compressed=False, 
    gex_only=False
)
# Out:
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.

# %%
adata.var()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 adata.var()
#
# TypeError: 'DataFrame' object is not callable

# %%
output_file = INTERMEDIATE_DIR / "00_loaded_raw.h5ad"
adata.write_h5ad(output_file)
print("Saved:", output_file)
# Out:
# Saved: /mnt/sata4/Dhruv_2025/Projects_31926/RNA_Seq/Kallies_Sci_Immuno_2025/objects/00_loaded_raw.h5ad
